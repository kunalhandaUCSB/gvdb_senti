# %%
import transformers
from transformers import BertModel, BertTokenizer, AdamW, get_linear_schedule_with_warmup
from keras.preprocessing.sequence import pad_sequences
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
import numpy as np
import pandas as pd
from nltk.tokenize import word_tokenize
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from collections import defaultdict
from textwrap import wrap
from collections import ChainMap

import json

from torch import nn, optim
from torch.utils.data import Dataset, DataLoader

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# 'GeForce RTX 2070 SUPER'

# %%
og_df = pd.read_csv("gvdb-aggregated-db\Articles-with-extracted-info.tsv", sep='\t')
og_df.head()
# Out:
#       Article_url                                 Article_title  \
# 0  gold-data1.com     Man shoots self accidentally while in car
# 1  gold-data1.com     Man shoots self accidentally while in car
# 2  gold-data2.com  Man accidentally shoots himself cleaning gun
# 3  gold-data2.com  Man accidentally shoots himself cleaning gun
# 4  gold-data1.com     Man shoots self accidentally while in car
#
#                                            Full_text  \
# 0  Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 1  Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 2  BLOOMINGTON, IL - On Thursday evening, Septemb...
# 3  BLOOMINGTON, IL - On Thursday evening, Septemb...
# 4  Atlantic City, Wyo. 26-year-old Joe Henderson ...
#
#                                                 Json  \
# 0  {"circumstances":{"number-of-shots-fired":{"en...
# 1  {"circumstances":{"number-of-shots-fired":{"en...
# 2  {"circumstances":{"number-of-shots-fired":{"en...
# 3  {"circumstances":{"number-of-shots-fired":{"en...
# 4  {"circumstances":{"number-of-shots-fired":{"en...
#
#             Publication_date
# 0  2015-01-03 00:00:00+00:00
# 1  2015-01-03 00:00:00+00:00
# 2  2013-09-06 00:00:00+00:00
# 3  2013-09-06 00:00:00+00:00
# 4  2015-01-03 00:00:00+00:00

# %%
print(og_df.iloc[0] == og_df.iloc[0])
# Out:
# Article_url         True
# Article_title       True
# Full_text           True
# Json                True
# Publication_date    True
# Name: 0, dtype: bool

# %%
#df = og_df.drop_duplicates()

# %%
df = og_df
df
# Out:
#                                              Article_url  \
# 0                                         gold-data1.com
# 1                                         gold-data1.com
# 2                                         gold-data2.com
# 3                                         gold-data2.com
# 4                                         gold-data1.com
# ...                                                  ...
# 23898  http://www.nbcphiladelphia.com/news/local/Woma...
# 23899                                    gold-data15.com
# 23900                                    gold-data16.com
# 23901                            http://gold-data17.com/
# 23902                            http://gold-data18.com/
#
#                                            Article_title  \
# 0              Man shoots self accidentally while in car
# 1              Man shoots self accidentally while in car
# 2           Man accidentally shoots himself cleaning gun
# 3           Man accidentally shoots himself cleaning gun
# 4              Man shoots self accidentally while in car
# ...                                                  ...
# 23898  Woman Dies After Being Shot in Head Along Nice...
# 23899  Bridgeport man murdered in 9th homocide this year
# 23900             23 year old man shot dead in nightclub
# 23901       Man accidentally shoots himself cleaning gun
# 23902          Man shoots self accidentally while in car
#
#                                                Full_text  \
# 0      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 1      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 2      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 3      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 4      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# ...                                                  ...
# 23898  A woman has been killed after being shot in th...
# 23899  Bridgeport, Connecticut -- Christopher Pettway...
# 23900  OAKLAND, CA -- A 23-year-old Hispanic man was ...
# 23901  BLOOMINGTON, IL - On Thursday evening, Septemb...
# 23902  Atlantic City, Wyo. 26-year-old Joe Henderson ...
#
#                                                     Json  \
# 0      {"circumstances":{"number-of-shots-fired":{"en...
# 1      {"circumstances":{"number-of-shots-fired":{"en...
# 2      {"circumstances":{"number-of-shots-fired":{"en...
# 3      {"circumstances":{"number-of-shots-fired":{"en...
# 4      {"circumstances":{"number-of-shots-fired":{"en...
# ...                                                  ...
# 23898  {"circumstances":{"number-of-shots-fired":{"en...
# 23899  {"circumstances":{"number-of-shots-fired":{"en...
# 23900  {"circumstances":{"number-of-shots-fired":{"en...
# 23901  {"circumstances":{"number-of-shots-fired":{"en...
# 23902  {"circumstances":{"number-of-shots-fired":{"en...
#
#                 Publication_date
# 0      2015-01-03 00:00:00+00:00
# 1      2015-01-03 00:00:00+00:00
# 2      2013-09-06 00:00:00+00:00
# 3      2013-09-06 00:00:00+00:00
# 4      2015-01-03 00:00:00+00:00
# ...                          ...
# 23898  2017-11-09 00:00:00+00:00
# 23899  2014-07-29 00:00:00+00:00
# 23900  2014-10-21 00:00:00+00:00
# 23901  2013-09-06 00:00:00+00:00
# 23902  2015-01-03 00:00:00+00:00
#
# [23903 rows x 5 columns]

# %%
df.shape
# Out:
# (23903, 5)

# %%
df = df.join(df['Json'].apply(json.loads).apply(pd.Series))

# %%
df.columns = df.columns.str.strip().str.lower().str.replace('-', '_')

# %%
df
# Out:
#                                              article_url  \
# 0                                         gold-data1.com
# 1                                         gold-data1.com
# 2                                         gold-data2.com
# 3                                         gold-data2.com
# 4                                         gold-data1.com
# ...                                                  ...
# 23898  http://www.nbcphiladelphia.com/news/local/Woma...
# 23899                                    gold-data15.com
# 23900                                    gold-data16.com
# 23901                            http://gold-data17.com/
# 23902                            http://gold-data18.com/
#
#                                            article_title  \
# 0              Man shoots self accidentally while in car
# 1              Man shoots self accidentally while in car
# 2           Man accidentally shoots himself cleaning gun
# 3           Man accidentally shoots himself cleaning gun
# 4              Man shoots self accidentally while in car
# ...                                                  ...
# 23898  Woman Dies After Being Shot in Head Along Nice...
# 23899  Bridgeport man murdered in 9th homocide this year
# 23900             23 year old man shot dead in nightclub
# 23901       Man accidentally shoots himself cleaning gun
# 23902          Man shoots self accidentally while in car
#
#                                                full_text  \
# 0      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 1      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 2      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 3      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 4      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# ...                                                  ...
# 23898  A woman has been killed after being shot in th...
# 23899  Bridgeport, Connecticut -- Christopher Pettway...
# 23900  OAKLAND, CA -- A 23-year-old Hispanic man was ...
# 23901  BLOOMINGTON, IL - On Thursday evening, Septemb...
# 23902  Atlantic City, Wyo. 26-year-old Joe Henderson ...
#
#                                                     json  \
# 0      {"circumstances":{"number-of-shots-fired":{"en...
# 1      {"circumstances":{"number-of-shots-fired":{"en...
# 2      {"circumstances":{"number-of-shots-fired":{"en...
# 3      {"circumstances":{"number-of-shots-fired":{"en...
# 4      {"circumstances":{"number-of-shots-fired":{"en...
# ...                                                  ...
# 23898  {"circumstances":{"number-of-shots-fired":{"en...
# 23899  {"circumstances":{"number-of-shots-fired":{"en...
# 23900  {"circumstances":{"number-of-shots-fired":{"en...
# 23901  {"circumstances":{"number-of-shots-fired":{"en...
# 23902  {"circumstances":{"number-of-shots-fired":{"en...
#
#                 publication_date  \
# 0      2015-01-03 00:00:00+00:00
# 1      2015-01-03 00:00:00+00:00
# 2      2013-09-06 00:00:00+00:00
# 3      2013-09-06 00:00:00+00:00
# 4      2015-01-03 00:00:00+00:00
# ...                          ...
# 23898  2017-11-09 00:00:00+00:00
# 23899  2014-07-29 00:00:00+00:00
# 23900  2014-10-21 00:00:00+00:00
# 23901  2013-09-06 00:00:00+00:00
# 23902  2015-01-03 00:00:00+00:00
#
#                                            circumstances  \
# 0      {'number-of-shots-fired': {'endIndex': 451, 's...
# 1      {'number-of-shots-fired': {'endIndex': 451, 's...
# 2      {'number-of-shots-fired': {'endIndex': -1, 'st...
# 3      {'number-of-shots-fired': {'endIndex': 122, 's...
# 4      {'number-of-shots-fired': {'endIndex': -1, 'st...
# ...                                                  ...
# 23898  {'number-of-shots-fired': {'endIndex': -1, 'st...
# 23899  {'number-of-shots-fired': {'endIndex': 1073, '...
# 23900  {'number-of-shots-fired': {'endIndex': -1, 'st...
# 23901  {'number-of-shots-fired': {'endIndex': 165, 's...
# 23902  {'number-of-shots-fired': {'endIndex': 492, 's...
#
#                                            date_and_time  \
# 0      {'city': {'endIndex': 8, 'startIndex': 0, 'val...
# 1      {'city': {'endIndex': 8, 'startIndex': 0, 'val...
# 2      {'city': {'endIndex': 11, 'startIndex': 0, 'va...
# 3      {'city': {'endIndex': 11, 'startIndex': 0, 'va...
# 4      {'city': {'endIndex': 13, 'startIndex': 12, 'v...
# ...                                                  ...
# 23898  {'city': {'endIndex': 153, 'startIndex': 140, ...
# 23899  {'city': {'endIndex': 59, 'startIndex': 49, 'v...
# 23900  {'city': {'endIndex': 46, 'startIndex': 38, 'v...
# 23901  {'city': {'endIndex': 55, 'startIndex': 44, 'v...
# 23902  {'city': {'endIndex': 54, 'startIndex': 41, 'v...
#
#                                                   radio1  \
# 0      {'The firearm was used during another crime.':...
# 1      {'The firearm was used during another crime.':...
# 2      {'The firearm was used during another crime.':...
# 3      {'The firearm was used during another crime.':...
# 4      {'The firearm was used during another crime.':...
# ...                                                  ...
# 23898  {'The firearm was used during another crime.':...
# 23899  {'The firearm was used during another crime.':...
# 23900  {'The firearm was used during another crime.':...
# 23901  {'The firearm was used during another crime.':...
# 23902  {'The firearm was used during another crime.':...
#
#                                                   radio2  \
# 0      {'Alcohol was involved.': 'No', 'Drugs (other ...
# 1      {'Alcohol was involved.': 'No', 'Drugs (other ...
# 2      {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 3      {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 4      {'Alcohol was involved.': 'Not mentioned', 'Dr...
# ...                                                  ...
# 23898  {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 23899  {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 23900  {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 23901  {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 23902  {'Alcohol was involved.': 'Not mentioned', 'Dr...
#
#                                                   radio3  \
# 0      {'The firearm was owned by the victim/victims ...
# 1      {'The firearm was owned by the victim/victims ...
# 2      {'The firearm was owned by the victim/victims ...
# 3      {'The firearm was owned by the victim/victims ...
# 4      {'The firearm was owned by the victim/victims ...
# ...                                                  ...
# 23898  {'The firearm was owned by the victim/victims ...
# 23899  {'The firearm was owned by the victim/victims ...
# 23900  {'The firearm was owned by the victim/victims ...
# 23901  {'The firearm was owned by the victim/victims ...
# 23902  {'The firearm was owned by the victim/victims ...
#
#                                          shooter_section  \
# 0      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# 1      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# 2      [{'age': {'endIndex': 65, 'startIndex': 54, 'v...
# 3      [{'age': {'endIndex': 56, 'startIndex': 54, 'v...
# 4      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# ...                                                  ...
# 23898                                                 []
# 23899                                                 []
# 23900                                                 []
# 23901  [{'age': {'endIndex': 100, 'startIndex': 98, '...
# 23902  [{'age': {'endIndex': 63, 'startIndex': 61, 'v...
#
#                                           victim_section
# 0      [{'age': {'endIndex': 22, 'startIndex': 32, 'v...
# 1      [{'age': {'endIndex': 22, 'startIndex': 32, 'v...
# 2      [{'age': {'endIndex': 65, 'startIndex': 54, 'v...
# 3      [{'age': {'endIndex': 56, 'startIndex': 54, 'v...
# 4      [{'age': {'endIndex': -1, 'startIndex': -1, 'v...
# ...                                                  ...
# 23898  [{'age': {'endIndex': 182, 'startIndex': 179, ...
# 23899  [{'age': {'endIndex': 543, 'startIndex': 540, ...
# 23900  [{'age': {'endIndex': 57, 'startIndex': 55, 'v...
# 23901  [{'age': {'endIndex': 100, 'startIndex': 98, '...
# 23902  [{'age': {'endIndex': 63, 'startIndex': 61, 'v...
#
# [23903 rows x 12 columns]

# %%
df_s = pd.DataFrame(df.shooter_section)

# %%
df.shooter_section[2][0].get('race').get('value')
# sns.countplot(x='race', data = df.victim_section[0][0].get('race').get('value'))
# Out:
# 'white'

# %%
from collections import ChainMap
multiDct_to_single=[]
for i in range(len(df['shooter_section'])):
    qq=dict(ChainMap(*df['shooter_section'][i][::-1]))
    multiDct_to_single.append(qq)
df_flat= pd.DataFrame(multiDct_to_single)
df_flat
# Out:
#                                                      age gender  \
# 0      {'endIndex': 22, 'startIndex': 20, 'value': '26'}   Male
# 1      {'endIndex': 22, 'startIndex': 20, 'value': '26'}   Male
# 2      {'endIndex': 65, 'startIndex': 54, 'value': '2...   Male
# 3      {'endIndex': 56, 'startIndex': 54, 'value': '23'}   Male
# 4      {'endIndex': 22, 'startIndex': 20, 'value': '26'}   Male
# ...                                                  ...    ...
# 23898                                                NaN    NaN
# 23899                                                NaN    NaN
# 23900                                                NaN    NaN
# 23901  {'endIndex': 100, 'startIndex': 98, 'value': '...   Male
# 23902  {'endIndex': 63, 'startIndex': 61, 'value': '26'}   Male
#
#                                                     name  \
# 0      {'endIndex': 45, 'startIndex': 63, 'value': 'J...
# 1      {'endIndex': 45, 'startIndex': 63, 'value': 'J...
# 2        {'endIndex': -1, 'startIndex': -1, 'value': ''}
# 3        {'endIndex': -1, 'startIndex': -1, 'value': ''}
# 4      {'endIndex': 45, 'startIndex': 32, 'value': 'J...
# ...                                                  ...
# 23898                                                NaN
# 23899                                                NaN
# 23900                                                NaN
# 23901    {'endIndex': -1, 'startIndex': -1, 'value': ''}
# 23902  {'endIndex': 87, 'startIndex': 73, 'value': 'J...
#
#                                                     race
# 0        {'endIndex': -1, 'startIndex': -1, 'value': ''}
# 1        {'endIndex': -1, 'startIndex': -1, 'value': ''}
# 2      {'endIndex': 71, 'startIndex': 66, 'value': 'w...
# 3      {'endIndex': 71, 'startIndex': 66, 'value': 'w...
# 4        {'endIndex': -1, 'startIndex': -1, 'value': ''}
# ...                                                  ...
# 23898                                                NaN
# 23899                                                NaN
# 23900                                                NaN
# 23901  {'endIndex': 115, 'startIndex': 110, 'value': ...
# 23902    {'endIndex': -1, 'startIndex': -1, 'value': ''}
#
# [23903 rows x 4 columns]

# %%
def func(dict_):
    h=defaultdict(list)
    for j in dict_:
        if type(j)!=str:
            for i in j.items():
                h[i[0]].append(i[1])
    return h


t_=[]
g=defaultdict(list)
for i in range(len(df_flat['race'])):
    tdict = df_flat['race'][i]
    if not isinstance(tdict,float):
        t_.append(tdict.get('value').strip().lower())
    else:
        t_.append("NaN")
df_race = pd.DataFrame(t_)
df_race.columns = ["race"]
df_race
# Out:
#         race
# 0
# 1
# 2      white
# 3      white
# 4
# ...      ...
# 23898    NaN
# 23899    NaN
# 23900    NaN
# 23901  white
# 23902
#
# [23903 rows x 1 columns]

# %%
# sLength = len(df['article_title'])
#df = df.assign(df_race=pd.Series(np.random.randn(sLength)).values)
#df = df.join(df_race.apply(pd.Series))
df['race'] = df_race.values
df
# Out:
#                                              article_url  \
# 0                                         gold-data1.com
# 1                                         gold-data1.com
# 2                                         gold-data2.com
# 3                                         gold-data2.com
# 4                                         gold-data1.com
# ...                                                  ...
# 23898  http://www.nbcphiladelphia.com/news/local/Woma...
# 23899                                    gold-data15.com
# 23900                                    gold-data16.com
# 23901                            http://gold-data17.com/
# 23902                            http://gold-data18.com/
#
#                                            article_title  \
# 0              Man shoots self accidentally while in car
# 1              Man shoots self accidentally while in car
# 2           Man accidentally shoots himself cleaning gun
# 3           Man accidentally shoots himself cleaning gun
# 4              Man shoots self accidentally while in car
# ...                                                  ...
# 23898  Woman Dies After Being Shot in Head Along Nice...
# 23899  Bridgeport man murdered in 9th homocide this year
# 23900             23 year old man shot dead in nightclub
# 23901       Man accidentally shoots himself cleaning gun
# 23902          Man shoots self accidentally while in car
#
#                                                full_text  \
# 0      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 1      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 2      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 3      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 4      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# ...                                                  ...
# 23898  A woman has been killed after being shot in th...
# 23899  Bridgeport, Connecticut -- Christopher Pettway...
# 23900  OAKLAND, CA -- A 23-year-old Hispanic man was ...
# 23901  BLOOMINGTON, IL - On Thursday evening, Septemb...
# 23902  Atlantic City, Wyo. 26-year-old Joe Henderson ...
#
#                                                     json  \
# 0      {"circumstances":{"number-of-shots-fired":{"en...
# 1      {"circumstances":{"number-of-shots-fired":{"en...
# 2      {"circumstances":{"number-of-shots-fired":{"en...
# 3      {"circumstances":{"number-of-shots-fired":{"en...
# 4      {"circumstances":{"number-of-shots-fired":{"en...
# ...                                                  ...
# 23898  {"circumstances":{"number-of-shots-fired":{"en...
# 23899  {"circumstances":{"number-of-shots-fired":{"en...
# 23900  {"circumstances":{"number-of-shots-fired":{"en...
# 23901  {"circumstances":{"number-of-shots-fired":{"en...
# 23902  {"circumstances":{"number-of-shots-fired":{"en...
#
#                 publication_date  \
# 0      2015-01-03 00:00:00+00:00
# 1      2015-01-03 00:00:00+00:00
# 2      2013-09-06 00:00:00+00:00
# 3      2013-09-06 00:00:00+00:00
# 4      2015-01-03 00:00:00+00:00
# ...                          ...
# 23898  2017-11-09 00:00:00+00:00
# 23899  2014-07-29 00:00:00+00:00
# 23900  2014-10-21 00:00:00+00:00
# 23901  2013-09-06 00:00:00+00:00
# 23902  2015-01-03 00:00:00+00:00
#
#                                            circumstances  \
# 0      {'number-of-shots-fired': {'endIndex': 451, 's...
# 1      {'number-of-shots-fired': {'endIndex': 451, 's...
# 2      {'number-of-shots-fired': {'endIndex': -1, 'st...
# 3      {'number-of-shots-fired': {'endIndex': 122, 's...
# 4      {'number-of-shots-fired': {'endIndex': -1, 'st...
# ...                                                  ...
# 23898  {'number-of-shots-fired': {'endIndex': -1, 'st...
# 23899  {'number-of-shots-fired': {'endIndex': 1073, '...
# 23900  {'number-of-shots-fired': {'endIndex': -1, 'st...
# 23901  {'number-of-shots-fired': {'endIndex': 165, 's...
# 23902  {'number-of-shots-fired': {'endIndex': 492, 's...
#
#                                            date_and_time  \
# 0      {'city': {'endIndex': 8, 'startIndex': 0, 'val...
# 1      {'city': {'endIndex': 8, 'startIndex': 0, 'val...
# 2      {'city': {'endIndex': 11, 'startIndex': 0, 'va...
# 3      {'city': {'endIndex': 11, 'startIndex': 0, 'va...
# 4      {'city': {'endIndex': 13, 'startIndex': 12, 'v...
# ...                                                  ...
# 23898  {'city': {'endIndex': 153, 'startIndex': 140, ...
# 23899  {'city': {'endIndex': 59, 'startIndex': 49, 'v...
# 23900  {'city': {'endIndex': 46, 'startIndex': 38, 'v...
# 23901  {'city': {'endIndex': 55, 'startIndex': 44, 'v...
# 23902  {'city': {'endIndex': 54, 'startIndex': 41, 'v...
#
#                                                   radio1  \
# 0      {'The firearm was used during another crime.':...
# 1      {'The firearm was used during another crime.':...
# 2      {'The firearm was used during another crime.':...
# 3      {'The firearm was used during another crime.':...
# 4      {'The firearm was used during another crime.':...
# ...                                                  ...
# 23898  {'The firearm was used during another crime.':...
# 23899  {'The firearm was used during another crime.':...
# 23900  {'The firearm was used during another crime.':...
# 23901  {'The firearm was used during another crime.':...
# 23902  {'The firearm was used during another crime.':...
#
#                                                   radio2  \
# 0      {'Alcohol was involved.': 'No', 'Drugs (other ...
# 1      {'Alcohol was involved.': 'No', 'Drugs (other ...
# 2      {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 3      {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 4      {'Alcohol was involved.': 'Not mentioned', 'Dr...
# ...                                                  ...
# 23898  {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 23899  {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 23900  {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 23901  {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 23902  {'Alcohol was involved.': 'Not mentioned', 'Dr...
#
#                                                   radio3  \
# 0      {'The firearm was owned by the victim/victims ...
# 1      {'The firearm was owned by the victim/victims ...
# 2      {'The firearm was owned by the victim/victims ...
# 3      {'The firearm was owned by the victim/victims ...
# 4      {'The firearm was owned by the victim/victims ...
# ...                                                  ...
# 23898  {'The firearm was owned by the victim/victims ...
# 23899  {'The firearm was owned by the victim/victims ...
# 23900  {'The firearm was owned by the victim/victims ...
# 23901  {'The firearm was owned by the victim/victims ...
# 23902  {'The firearm was owned by the victim/victims ...
#
#                                          shooter_section  \
# 0      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# 1      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# 2      [{'age': {'endIndex': 65, 'startIndex': 54, 'v...
# 3      [{'age': {'endIndex': 56, 'startIndex': 54, 'v...
# 4      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# ...                                                  ...
# 23898                                                 []
# 23899                                                 []
# 23900                                                 []
# 23901  [{'age': {'endIndex': 100, 'startIndex': 98, '...
# 23902  [{'age': {'endIndex': 63, 'startIndex': 61, 'v...
#
#                                           victim_section   race
# 0      [{'age': {'endIndex': 22, 'startIndex': 32, 'v...
# 1      [{'age': {'endIndex': 22, 'startIndex': 32, 'v...
# 2      [{'age': {'endIndex': 65, 'startIndex': 54, 'v...  white
# 3      [{'age': {'endIndex': 56, 'startIndex': 54, 'v...  white
# 4      [{'age': {'endIndex': -1, 'startIndex': -1, 'v...
# ...                                                  ...    ...
# 23898  [{'age': {'endIndex': 182, 'startIndex': 179, ...    NaN
# 23899  [{'age': {'endIndex': 543, 'startIndex': 540, ...    NaN
# 23900  [{'age': {'endIndex': 57, 'startIndex': 55, 'v...    NaN
# 23901  [{'age': {'endIndex': 100, 'startIndex': 98, '...  white
# 23902  [{'age': {'endIndex': 63, 'startIndex': 61, 'v...
#
# [23903 rows x 13 columns]

# %%
#    if type(df_flat['race'][i])!=str:
#        t_.append(func(df_flat['race'][i]))
#    
#    else:
#        tups=tuple(zip(df_flat['race'][0][0].keys() ,
#                               ['Nope']*len(df_flat['race'][0][0].keys())))
#        for n in tups:
#            g[n[0]].append(n[1])
#        t_.append(g)

#print(pd.DataFrame(t_).url[0])
#print('--------------------')
#print(pd.DataFrame(t_).url[1])

#url_expand_=pd.DataFrame(t_)
#url_expand_

# %%
# shooters_list = list(df['shooter_section'].items())

# %%
# print(type(shooters_list))
# thislist = shooters_list[99][1]
# print(thislist)
# thislist[0]['race'].get('value')

# %%
# races = []
# for case in shooters_list:
    ## info_list = shooters_list[case][1]
    ## races.append(info_list[0]['race'].get('value'))
    ## print(case[1])
    # temp = case[1]
    # print(temp[0]['race'].get('value'))

# %%
df
# Out:
#                                              article_url  \
# 0                                         gold-data1.com
# 1                                         gold-data1.com
# 2                                         gold-data2.com
# 3                                         gold-data2.com
# 4                                         gold-data1.com
# ...                                                  ...
# 23898  http://www.nbcphiladelphia.com/news/local/Woma...
# 23899                                    gold-data15.com
# 23900                                    gold-data16.com
# 23901                            http://gold-data17.com/
# 23902                            http://gold-data18.com/
#
#                                            article_title  \
# 0              Man shoots self accidentally while in car
# 1              Man shoots self accidentally while in car
# 2           Man accidentally shoots himself cleaning gun
# 3           Man accidentally shoots himself cleaning gun
# 4              Man shoots self accidentally while in car
# ...                                                  ...
# 23898  Woman Dies After Being Shot in Head Along Nice...
# 23899  Bridgeport man murdered in 9th homocide this year
# 23900             23 year old man shot dead in nightclub
# 23901       Man accidentally shoots himself cleaning gun
# 23902          Man shoots self accidentally while in car
#
#                                                full_text  \
# 0      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 1      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 2      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 3      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 4      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# ...                                                  ...
# 23898  A woman has been killed after being shot in th...
# 23899  Bridgeport, Connecticut -- Christopher Pettway...
# 23900  OAKLAND, CA -- A 23-year-old Hispanic man was ...
# 23901  BLOOMINGTON, IL - On Thursday evening, Septemb...
# 23902  Atlantic City, Wyo. 26-year-old Joe Henderson ...
#
#                                                     json  \
# 0      {"circumstances":{"number-of-shots-fired":{"en...
# 1      {"circumstances":{"number-of-shots-fired":{"en...
# 2      {"circumstances":{"number-of-shots-fired":{"en...
# 3      {"circumstances":{"number-of-shots-fired":{"en...
# 4      {"circumstances":{"number-of-shots-fired":{"en...
# ...                                                  ...
# 23898  {"circumstances":{"number-of-shots-fired":{"en...
# 23899  {"circumstances":{"number-of-shots-fired":{"en...
# 23900  {"circumstances":{"number-of-shots-fired":{"en...
# 23901  {"circumstances":{"number-of-shots-fired":{"en...
# 23902  {"circumstances":{"number-of-shots-fired":{"en...
#
#                 publication_date  \
# 0      2015-01-03 00:00:00+00:00
# 1      2015-01-03 00:00:00+00:00
# 2      2013-09-06 00:00:00+00:00
# 3      2013-09-06 00:00:00+00:00
# 4      2015-01-03 00:00:00+00:00
# ...                          ...
# 23898  2017-11-09 00:00:00+00:00
# 23899  2014-07-29 00:00:00+00:00
# 23900  2014-10-21 00:00:00+00:00
# 23901  2013-09-06 00:00:00+00:00
# 23902  2015-01-03 00:00:00+00:00
#
#                                            circumstances  \
# 0      {'number-of-shots-fired': {'endIndex': 451, 's...
# 1      {'number-of-shots-fired': {'endIndex': 451, 's...
# 2      {'number-of-shots-fired': {'endIndex': -1, 'st...
# 3      {'number-of-shots-fired': {'endIndex': 122, 's...
# 4      {'number-of-shots-fired': {'endIndex': -1, 'st...
# ...                                                  ...
# 23898  {'number-of-shots-fired': {'endIndex': -1, 'st...
# 23899  {'number-of-shots-fired': {'endIndex': 1073, '...
# 23900  {'number-of-shots-fired': {'endIndex': -1, 'st...
# 23901  {'number-of-shots-fired': {'endIndex': 165, 's...
# 23902  {'number-of-shots-fired': {'endIndex': 492, 's...
#
#                                            date_and_time  \
# 0      {'city': {'endIndex': 8, 'startIndex': 0, 'val...
# 1      {'city': {'endIndex': 8, 'startIndex': 0, 'val...
# 2      {'city': {'endIndex': 11, 'startIndex': 0, 'va...
# 3      {'city': {'endIndex': 11, 'startIndex': 0, 'va...
# 4      {'city': {'endIndex': 13, 'startIndex': 12, 'v...
# ...                                                  ...
# 23898  {'city': {'endIndex': 153, 'startIndex': 140, ...
# 23899  {'city': {'endIndex': 59, 'startIndex': 49, 'v...
# 23900  {'city': {'endIndex': 46, 'startIndex': 38, 'v...
# 23901  {'city': {'endIndex': 55, 'startIndex': 44, 'v...
# 23902  {'city': {'endIndex': 54, 'startIndex': 41, 'v...
#
#                                                   radio1  \
# 0      {'The firearm was used during another crime.':...
# 1      {'The firearm was used during another crime.':...
# 2      {'The firearm was used during another crime.':...
# 3      {'The firearm was used during another crime.':...
# 4      {'The firearm was used during another crime.':...
# ...                                                  ...
# 23898  {'The firearm was used during another crime.':...
# 23899  {'The firearm was used during another crime.':...
# 23900  {'The firearm was used during another crime.':...
# 23901  {'The firearm was used during another crime.':...
# 23902  {'The firearm was used during another crime.':...
#
#                                                   radio2  \
# 0      {'Alcohol was involved.': 'No', 'Drugs (other ...
# 1      {'Alcohol was involved.': 'No', 'Drugs (other ...
# 2      {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 3      {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 4      {'Alcohol was involved.': 'Not mentioned', 'Dr...
# ...                                                  ...
# 23898  {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 23899  {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 23900  {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 23901  {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 23902  {'Alcohol was involved.': 'Not mentioned', 'Dr...
#
#                                                   radio3  \
# 0      {'The firearm was owned by the victim/victims ...
# 1      {'The firearm was owned by the victim/victims ...
# 2      {'The firearm was owned by the victim/victims ...
# 3      {'The firearm was owned by the victim/victims ...
# 4      {'The firearm was owned by the victim/victims ...
# ...                                                  ...
# 23898  {'The firearm was owned by the victim/victims ...
# 23899  {'The firearm was owned by the victim/victims ...
# 23900  {'The firearm was owned by the victim/victims ...
# 23901  {'The firearm was owned by the victim/victims ...
# 23902  {'The firearm was owned by the victim/victims ...
#
#                                          shooter_section  \
# 0      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# 1      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# 2      [{'age': {'endIndex': 65, 'startIndex': 54, 'v...
# 3      [{'age': {'endIndex': 56, 'startIndex': 54, 'v...
# 4      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# ...                                                  ...
# 23898                                                 []
# 23899                                                 []
# 23900                                                 []
# 23901  [{'age': {'endIndex': 100, 'startIndex': 98, '...
# 23902  [{'age': {'endIndex': 63, 'startIndex': 61, 'v...
#
#                                           victim_section   race
# 0      [{'age': {'endIndex': 22, 'startIndex': 32, 'v...
# 1      [{'age': {'endIndex': 22, 'startIndex': 32, 'v...
# 2      [{'age': {'endIndex': 65, 'startIndex': 54, 'v...  white
# 3      [{'age': {'endIndex': 56, 'startIndex': 54, 'v...  white
# 4      [{'age': {'endIndex': -1, 'startIndex': -1, 'v...
# ...                                                  ...    ...
# 23898  [{'age': {'endIndex': 182, 'startIndex': 179, ...    NaN
# 23899  [{'age': {'endIndex': 543, 'startIndex': 540, ...    NaN
# 23900  [{'age': {'endIndex': 57, 'startIndex': 55, 'v...    NaN
# 23901  [{'age': {'endIndex': 100, 'startIndex': 98, '...  white
# 23902  [{'age': {'endIndex': 63, 'startIndex': 61, 'v...
#
# [23903 rows x 13 columns]

# %%
import nltk

# %%
nltk.download("popular")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\khanda\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
df['tokenized_title'] = df["article_title"].apply(word_tokenize)

# %%
df
# Out:
#                                              article_url  \
# 0                                         gold-data1.com
# 1                                         gold-data1.com
# 2                                         gold-data2.com
# 3                                         gold-data2.com
# 4                                         gold-data1.com
# ...                                                  ...
# 23898  http://www.nbcphiladelphia.com/news/local/Woma...
# 23899                                    gold-data15.com
# 23900                                    gold-data16.com
# 23901                            http://gold-data17.com/
# 23902                            http://gold-data18.com/
#
#                                            article_title  \
# 0              Man shoots self accidentally while in car
# 1              Man shoots self accidentally while in car
# 2           Man accidentally shoots himself cleaning gun
# 3           Man accidentally shoots himself cleaning gun
# 4              Man shoots self accidentally while in car
# ...                                                  ...
# 23898  Woman Dies After Being Shot in Head Along Nice...
# 23899  Bridgeport man murdered in 9th homocide this year
# 23900             23 year old man shot dead in nightclub
# 23901       Man accidentally shoots himself cleaning gun
# 23902          Man shoots self accidentally while in car
#
#                                                full_text  \
# 0      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 1      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 2      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 3      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 4      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# ...                                                  ...
# 23898  A woman has been killed after being shot in th...
# 23899  Bridgeport, Connecticut -- Christopher Pettway...
# 23900  OAKLAND, CA -- A 23-year-old Hispanic man was ...
# 23901  BLOOMINGTON, IL - On Thursday evening, Septemb...
# 23902  Atlantic City, Wyo. 26-year-old Joe Henderson ...
#
#                                                     json  \
# 0      {"circumstances":{"number-of-shots-fired":{"en...
# 1      {"circumstances":{"number-of-shots-fired":{"en...
# 2      {"circumstances":{"number-of-shots-fired":{"en...
# 3      {"circumstances":{"number-of-shots-fired":{"en...
# 4      {"circumstances":{"number-of-shots-fired":{"en...
# ...                                                  ...
# 23898  {"circumstances":{"number-of-shots-fired":{"en...
# 23899  {"circumstances":{"number-of-shots-fired":{"en...
# 23900  {"circumstances":{"number-of-shots-fired":{"en...
# 23901  {"circumstances":{"number-of-shots-fired":{"en...
# 23902  {"circumstances":{"number-of-shots-fired":{"en...
#
#                 publication_date  \
# 0      2015-01-03 00:00:00+00:00
# 1      2015-01-03 00:00:00+00:00
# 2      2013-09-06 00:00:00+00:00
# 3      2013-09-06 00:00:00+00:00
# 4      2015-01-03 00:00:00+00:00
# ...                          ...
# 23898  2017-11-09 00:00:00+00:00
# 23899  2014-07-29 00:00:00+00:00
# 23900  2014-10-21 00:00:00+00:00
# 23901  2013-09-06 00:00:00+00:00
# 23902  2015-01-03 00:00:00+00:00
#
#                                            circumstances  \
# 0      {'number-of-shots-fired': {'endIndex': 451, 's...
# 1      {'number-of-shots-fired': {'endIndex': 451, 's...
# 2      {'number-of-shots-fired': {'endIndex': -1, 'st...
# 3      {'number-of-shots-fired': {'endIndex': 122, 's...
# 4      {'number-of-shots-fired': {'endIndex': -1, 'st...
# ...                                                  ...
# 23898  {'number-of-shots-fired': {'endIndex': -1, 'st...
# 23899  {'number-of-shots-fired': {'endIndex': 1073, '...
# 23900  {'number-of-shots-fired': {'endIndex': -1, 'st...
# 23901  {'number-of-shots-fired': {'endIndex': 165, 's...
# 23902  {'number-of-shots-fired': {'endIndex': 492, 's...
#
#                                            date_and_time  \
# 0      {'city': {'endIndex': 8, 'startIndex': 0, 'val...
# 1      {'city': {'endIndex': 8, 'startIndex': 0, 'val...
# 2      {'city': {'endIndex': 11, 'startIndex': 0, 'va...
# 3      {'city': {'endIndex': 11, 'startIndex': 0, 'va...
# 4      {'city': {'endIndex': 13, 'startIndex': 12, 'v...
# ...                                                  ...
# 23898  {'city': {'endIndex': 153, 'startIndex': 140, ...
# 23899  {'city': {'endIndex': 59, 'startIndex': 49, 'v...
# 23900  {'city': {'endIndex': 46, 'startIndex': 38, 'v...
# 23901  {'city': {'endIndex': 55, 'startIndex': 44, 'v...
# 23902  {'city': {'endIndex': 54, 'startIndex': 41, 'v...
#
#                                                   radio1  \
# 0      {'The firearm was used during another crime.':...
# 1      {'The firearm was used during another crime.':...
# 2      {'The firearm was used during another crime.':...
# 3      {'The firearm was used during another crime.':...
# 4      {'The firearm was used during another crime.':...
# ...                                                  ...
# 23898  {'The firearm was used during another crime.':...
# 23899  {'The firearm was used during another crime.':...
# 23900  {'The firearm was used during another crime.':...
# 23901  {'The firearm was used during another crime.':...
# 23902  {'The firearm was used during another crime.':...
#
#                                                   radio2  \
# 0      {'Alcohol was involved.': 'No', 'Drugs (other ...
# 1      {'Alcohol was involved.': 'No', 'Drugs (other ...
# 2      {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 3      {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 4      {'Alcohol was involved.': 'Not mentioned', 'Dr...
# ...                                                  ...
# 23898  {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 23899  {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 23900  {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 23901  {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 23902  {'Alcohol was involved.': 'Not mentioned', 'Dr...
#
#                                                   radio3  \
# 0      {'The firearm was owned by the victim/victims ...
# 1      {'The firearm was owned by the victim/victims ...
# 2      {'The firearm was owned by the victim/victims ...
# 3      {'The firearm was owned by the victim/victims ...
# 4      {'The firearm was owned by the victim/victims ...
# ...                                                  ...
# 23898  {'The firearm was owned by the victim/victims ...
# 23899  {'The firearm was owned by the victim/victims ...
# 23900  {'The firearm was owned by the victim/victims ...
# 23901  {'The firearm was owned by the victim/victims ...
# 23902  {'The firearm was owned by the victim/victims ...
#
#                                          shooter_section  \
# 0      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# 1      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# 2      [{'age': {'endIndex': 65, 'startIndex': 54, 'v...
# 3      [{'age': {'endIndex': 56, 'startIndex': 54, 'v...
# 4      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# ...                                                  ...
# 23898                                                 []
# 23899                                                 []
# 23900                                                 []
# 23901  [{'age': {'endIndex': 100, 'startIndex': 98, '...
# 23902  [{'age': {'endIndex': 63, 'startIndex': 61, 'v...
#
#                                           victim_section   race  \
# 0      [{'age': {'endIndex': 22, 'startIndex': 32, 'v...
# 1      [{'age': {'endIndex': 22, 'startIndex': 32, 'v...
# 2      [{'age': {'endIndex': 65, 'startIndex': 54, 'v...  white
# 3      [{'age': {'endIndex': 56, 'startIndex': 54, 'v...  white
# 4      [{'age': {'endIndex': -1, 'startIndex': -1, 'v...
# ...                                                  ...    ...
# 23898  [{'age': {'endIndex': 182, 'startIndex': 179, ...    NaN
# 23899  [{'age': {'endIndex': 543, 'startIndex': 540, ...    NaN
# 23900  [{'age': {'endIndex': 57, 'startIndex': 55, 'v...    NaN
# 23901  [{'age': {'endIndex': 100, 'startIndex': 98, '...  white
# 23902  [{'age': {'endIndex': 63, 'startIndex': 61, 'v...
#
#                                          tokenized_title
# 0      [Man, shoots, self, accidentally, while, in, car]
# 1      [Man, shoots, self, accidentally, while, in, car]
# 2      [Man, accidentally, shoots, himself, cleaning,...
# 3      [Man, accidentally, shoots, himself, cleaning,...
# 4      [Man, shoots, self, accidentally, while, in, car]
# ...                                                  ...
# 23898  [Woman, Dies, After, Being, Shot, in, Head, Al...
# 23899  [Bridgeport, man, murdered, in, 9th, homocide,...
# 23900    [23, year, old, man, shot, dead, in, nightclub]
# 23901  [Man, accidentally, shoots, himself, cleaning,...
# 23902  [Man, shoots, self, accidentally, while, in, car]
#
# [23903 rows x 14 columns]

# %%
df
# Out:
#                                              article_url  \
# 0                                         gold-data1.com
# 1                                         gold-data1.com
# 2                                         gold-data2.com
# 3                                         gold-data2.com
# 4                                         gold-data1.com
# ...                                                  ...
# 23898  http://www.nbcphiladelphia.com/news/local/Woma...
# 23899                                    gold-data15.com
# 23900                                    gold-data16.com
# 23901                            http://gold-data17.com/
# 23902                            http://gold-data18.com/
#
#                                            article_title  \
# 0              Man shoots self accidentally while in car
# 1              Man shoots self accidentally while in car
# 2           Man accidentally shoots himself cleaning gun
# 3           Man accidentally shoots himself cleaning gun
# 4              Man shoots self accidentally while in car
# ...                                                  ...
# 23898  Woman Dies After Being Shot in Head Along Nice...
# 23899  Bridgeport man murdered in 9th homocide this year
# 23900             23 year old man shot dead in nightclub
# 23901       Man accidentally shoots himself cleaning gun
# 23902          Man shoots self accidentally while in car
#
#                                                full_text  \
# 0      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 1      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 2      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 3      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 4      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# ...                                                  ...
# 23898  A woman has been killed after being shot in th...
# 23899  Bridgeport, Connecticut -- Christopher Pettway...
# 23900  OAKLAND, CA -- A 23-year-old Hispanic man was ...
# 23901  BLOOMINGTON, IL - On Thursday evening, Septemb...
# 23902  Atlantic City, Wyo. 26-year-old Joe Henderson ...
#
#                                                     json  \
# 0      {"circumstances":{"number-of-shots-fired":{"en...
# 1      {"circumstances":{"number-of-shots-fired":{"en...
# 2      {"circumstances":{"number-of-shots-fired":{"en...
# 3      {"circumstances":{"number-of-shots-fired":{"en...
# 4      {"circumstances":{"number-of-shots-fired":{"en...
# ...                                                  ...
# 23898  {"circumstances":{"number-of-shots-fired":{"en...
# 23899  {"circumstances":{"number-of-shots-fired":{"en...
# 23900  {"circumstances":{"number-of-shots-fired":{"en...
# 23901  {"circumstances":{"number-of-shots-fired":{"en...
# 23902  {"circumstances":{"number-of-shots-fired":{"en...
#
#                 publication_date  \
# 0      2015-01-03 00:00:00+00:00
# 1      2015-01-03 00:00:00+00:00
# 2      2013-09-06 00:00:00+00:00
# 3      2013-09-06 00:00:00+00:00
# 4      2015-01-03 00:00:00+00:00
# ...                          ...
# 23898  2017-11-09 00:00:00+00:00
# 23899  2014-07-29 00:00:00+00:00
# 23900  2014-10-21 00:00:00+00:00
# 23901  2013-09-06 00:00:00+00:00
# 23902  2015-01-03 00:00:00+00:00
#
#                                            circumstances  \
# 0      {'number-of-shots-fired': {'endIndex': 451, 's...
# 1      {'number-of-shots-fired': {'endIndex': 451, 's...
# 2      {'number-of-shots-fired': {'endIndex': -1, 'st...
# 3      {'number-of-shots-fired': {'endIndex': 122, 's...
# 4      {'number-of-shots-fired': {'endIndex': -1, 'st...
# ...                                                  ...
# 23898  {'number-of-shots-fired': {'endIndex': -1, 'st...
# 23899  {'number-of-shots-fired': {'endIndex': 1073, '...
# 23900  {'number-of-shots-fired': {'endIndex': -1, 'st...
# 23901  {'number-of-shots-fired': {'endIndex': 165, 's...
# 23902  {'number-of-shots-fired': {'endIndex': 492, 's...
#
#                                            date_and_time  \
# 0      {'city': {'endIndex': 8, 'startIndex': 0, 'val...
# 1      {'city': {'endIndex': 8, 'startIndex': 0, 'val...
# 2      {'city': {'endIndex': 11, 'startIndex': 0, 'va...
# 3      {'city': {'endIndex': 11, 'startIndex': 0, 'va...
# 4      {'city': {'endIndex': 13, 'startIndex': 12, 'v...
# ...                                                  ...
# 23898  {'city': {'endIndex': 153, 'startIndex': 140, ...
# 23899  {'city': {'endIndex': 59, 'startIndex': 49, 'v...
# 23900  {'city': {'endIndex': 46, 'startIndex': 38, 'v...
# 23901  {'city': {'endIndex': 55, 'startIndex': 44, 'v...
# 23902  {'city': {'endIndex': 54, 'startIndex': 41, 'v...
#
#                                                   radio1  \
# 0      {'The firearm was used during another crime.':...
# 1      {'The firearm was used during another crime.':...
# 2      {'The firearm was used during another crime.':...
# 3      {'The firearm was used during another crime.':...
# 4      {'The firearm was used during another crime.':...
# ...                                                  ...
# 23898  {'The firearm was used during another crime.':...
# 23899  {'The firearm was used during another crime.':...
# 23900  {'The firearm was used during another crime.':...
# 23901  {'The firearm was used during another crime.':...
# 23902  {'The firearm was used during another crime.':...
#
#                                                   radio2  \
# 0      {'Alcohol was involved.': 'No', 'Drugs (other ...
# 1      {'Alcohol was involved.': 'No', 'Drugs (other ...
# 2      {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 3      {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 4      {'Alcohol was involved.': 'Not mentioned', 'Dr...
# ...                                                  ...
# 23898  {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 23899  {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 23900  {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 23901  {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 23902  {'Alcohol was involved.': 'Not mentioned', 'Dr...
#
#                                                   radio3  \
# 0      {'The firearm was owned by the victim/victims ...
# 1      {'The firearm was owned by the victim/victims ...
# 2      {'The firearm was owned by the victim/victims ...
# 3      {'The firearm was owned by the victim/victims ...
# 4      {'The firearm was owned by the victim/victims ...
# ...                                                  ...
# 23898  {'The firearm was owned by the victim/victims ...
# 23899  {'The firearm was owned by the victim/victims ...
# 23900  {'The firearm was owned by the victim/victims ...
# 23901  {'The firearm was owned by the victim/victims ...
# 23902  {'The firearm was owned by the victim/victims ...
#
#                                          shooter_section  \
# 0      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# 1      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# 2      [{'age': {'endIndex': 65, 'startIndex': 54, 'v...
# 3      [{'age': {'endIndex': 56, 'startIndex': 54, 'v...
# 4      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# ...                                                  ...
# 23898                                                 []
# 23899                                                 []
# 23900                                                 []
# 23901  [{'age': {'endIndex': 100, 'startIndex': 98, '...
# 23902  [{'age': {'endIndex': 63, 'startIndex': 61, 'v...
#
#                                           victim_section   race  \
# 0      [{'age': {'endIndex': 22, 'startIndex': 32, 'v...
# 1      [{'age': {'endIndex': 22, 'startIndex': 32, 'v...
# 2      [{'age': {'endIndex': 65, 'startIndex': 54, 'v...  white
# 3      [{'age': {'endIndex': 56, 'startIndex': 54, 'v...  white
# 4      [{'age': {'endIndex': -1, 'startIndex': -1, 'v...
# ...                                                  ...    ...
# 23898  [{'age': {'endIndex': 182, 'startIndex': 179, ...    NaN
# 23899  [{'age': {'endIndex': 543, 'startIndex': 540, ...    NaN
# 23900  [{'age': {'endIndex': 57, 'startIndex': 55, 'v...    NaN
# 23901  [{'age': {'endIndex': 100, 'startIndex': 98, '...  white
# 23902  [{'age': {'endIndex': 63, 'startIndex': 61, 'v...
#
#                                          tokenized_title
# 0      [Man, shoots, self, accidentally, while, in, car]
# 1      [Man, shoots, self, accidentally, while, in, car]
# 2      [Man, accidentally, shoots, himself, cleaning,...
# 3      [Man, accidentally, shoots, himself, cleaning,...
# 4      [Man, shoots, self, accidentally, while, in, car]
# ...                                                  ...
# 23898  [Woman, Dies, After, Being, Shot, in, Head, Al...
# 23899  [Bridgeport, man, murdered, in, 9th, homocide,...
# 23900    [23, year, old, man, shot, dead, in, nightclub]
# 23901  [Man, accidentally, shoots, himself, cleaning,...
# 23902  [Man, shoots, self, accidentally, while, in, car]
#
# [23903 rows x 14 columns]

# %%
v = TfidfVectorizer()
x = v.fit_transform(df['article_title'])

# %%
df['title_vect'] = list(x)

# %%
df
# Out:
#                                              article_url  \
# 0                                         gold-data1.com
# 1                                         gold-data1.com
# 2                                         gold-data2.com
# 3                                         gold-data2.com
# 4                                         gold-data1.com
# ...                                                  ...
# 23898  http://www.nbcphiladelphia.com/news/local/Woma...
# 23899                                    gold-data15.com
# 23900                                    gold-data16.com
# 23901                            http://gold-data17.com/
# 23902                            http://gold-data18.com/
#
#                                            article_title  \
# 0              Man shoots self accidentally while in car
# 1              Man shoots self accidentally while in car
# 2           Man accidentally shoots himself cleaning gun
# 3           Man accidentally shoots himself cleaning gun
# 4              Man shoots self accidentally while in car
# ...                                                  ...
# 23898  Woman Dies After Being Shot in Head Along Nice...
# 23899  Bridgeport man murdered in 9th homocide this year
# 23900             23 year old man shot dead in nightclub
# 23901       Man accidentally shoots himself cleaning gun
# 23902          Man shoots self accidentally while in car
#
#                                                full_text  \
# 0      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 1      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# 2      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 3      BLOOMINGTON, IL - On Thursday evening, Septemb...
# 4      Atlantic City, Wyo. 26-year-old Joe Henderson ...
# ...                                                  ...
# 23898  A woman has been killed after being shot in th...
# 23899  Bridgeport, Connecticut -- Christopher Pettway...
# 23900  OAKLAND, CA -- A 23-year-old Hispanic man was ...
# 23901  BLOOMINGTON, IL - On Thursday evening, Septemb...
# 23902  Atlantic City, Wyo. 26-year-old Joe Henderson ...
#
#                                                     json  \
# 0      {"circumstances":{"number-of-shots-fired":{"en...
# 1      {"circumstances":{"number-of-shots-fired":{"en...
# 2      {"circumstances":{"number-of-shots-fired":{"en...
# 3      {"circumstances":{"number-of-shots-fired":{"en...
# 4      {"circumstances":{"number-of-shots-fired":{"en...
# ...                                                  ...
# 23898  {"circumstances":{"number-of-shots-fired":{"en...
# 23899  {"circumstances":{"number-of-shots-fired":{"en...
# 23900  {"circumstances":{"number-of-shots-fired":{"en...
# 23901  {"circumstances":{"number-of-shots-fired":{"en...
# 23902  {"circumstances":{"number-of-shots-fired":{"en...
#
#                 publication_date  \
# 0      2015-01-03 00:00:00+00:00
# 1      2015-01-03 00:00:00+00:00
# 2      2013-09-06 00:00:00+00:00
# 3      2013-09-06 00:00:00+00:00
# 4      2015-01-03 00:00:00+00:00
# ...                          ...
# 23898  2017-11-09 00:00:00+00:00
# 23899  2014-07-29 00:00:00+00:00
# 23900  2014-10-21 00:00:00+00:00
# 23901  2013-09-06 00:00:00+00:00
# 23902  2015-01-03 00:00:00+00:00
#
#                                            circumstances  \
# 0      {'number-of-shots-fired': {'endIndex': 451, 's...
# 1      {'number-of-shots-fired': {'endIndex': 451, 's...
# 2      {'number-of-shots-fired': {'endIndex': -1, 'st...
# 3      {'number-of-shots-fired': {'endIndex': 122, 's...
# 4      {'number-of-shots-fired': {'endIndex': -1, 'st...
# ...                                                  ...
# 23898  {'number-of-shots-fired': {'endIndex': -1, 'st...
# 23899  {'number-of-shots-fired': {'endIndex': 1073, '...
# 23900  {'number-of-shots-fired': {'endIndex': -1, 'st...
# 23901  {'number-of-shots-fired': {'endIndex': 165, 's...
# 23902  {'number-of-shots-fired': {'endIndex': 492, 's...
#
#                                            date_and_time  \
# 0      {'city': {'endIndex': 8, 'startIndex': 0, 'val...
# 1      {'city': {'endIndex': 8, 'startIndex': 0, 'val...
# 2      {'city': {'endIndex': 11, 'startIndex': 0, 'va...
# 3      {'city': {'endIndex': 11, 'startIndex': 0, 'va...
# 4      {'city': {'endIndex': 13, 'startIndex': 12, 'v...
# ...                                                  ...
# 23898  {'city': {'endIndex': 153, 'startIndex': 140, ...
# 23899  {'city': {'endIndex': 59, 'startIndex': 49, 'v...
# 23900  {'city': {'endIndex': 46, 'startIndex': 38, 'v...
# 23901  {'city': {'endIndex': 55, 'startIndex': 44, 'v...
# 23902  {'city': {'endIndex': 54, 'startIndex': 41, 'v...
#
#                                                   radio1  \
# 0      {'The firearm was used during another crime.':...
# 1      {'The firearm was used during another crime.':...
# 2      {'The firearm was used during another crime.':...
# 3      {'The firearm was used during another crime.':...
# 4      {'The firearm was used during another crime.':...
# ...                                                  ...
# 23898  {'The firearm was used during another crime.':...
# 23899  {'The firearm was used during another crime.':...
# 23900  {'The firearm was used during another crime.':...
# 23901  {'The firearm was used during another crime.':...
# 23902  {'The firearm was used during another crime.':...
#
#                                                   radio2  \
# 0      {'Alcohol was involved.': 'No', 'Drugs (other ...
# 1      {'Alcohol was involved.': 'No', 'Drugs (other ...
# 2      {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 3      {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 4      {'Alcohol was involved.': 'Not mentioned', 'Dr...
# ...                                                  ...
# 23898  {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 23899  {'Alcohol was involved.': 'Not mentioned', 'Dr...
# 23900  {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 23901  {'Alcohol was involved.': 'Yes', 'Drugs (other...
# 23902  {'Alcohol was involved.': 'Not mentioned', 'Dr...
#
#                                                   radio3  \
# 0      {'The firearm was owned by the victim/victims ...
# 1      {'The firearm was owned by the victim/victims ...
# 2      {'The firearm was owned by the victim/victims ...
# 3      {'The firearm was owned by the victim/victims ...
# 4      {'The firearm was owned by the victim/victims ...
# ...                                                  ...
# 23898  {'The firearm was owned by the victim/victims ...
# 23899  {'The firearm was owned by the victim/victims ...
# 23900  {'The firearm was owned by the victim/victims ...
# 23901  {'The firearm was owned by the victim/victims ...
# 23902  {'The firearm was owned by the victim/victims ...
#
#                                          shooter_section  \
# 0      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# 1      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# 2      [{'age': {'endIndex': 65, 'startIndex': 54, 'v...
# 3      [{'age': {'endIndex': 56, 'startIndex': 54, 'v...
# 4      [{'age': {'endIndex': 22, 'startIndex': 20, 'v...
# ...                                                  ...
# 23898                                                 []
# 23899                                                 []
# 23900                                                 []
# 23901  [{'age': {'endIndex': 100, 'startIndex': 98, '...
# 23902  [{'age': {'endIndex': 63, 'startIndex': 61, 'v...
#
#                                           victim_section   race  \
# 0      [{'age': {'endIndex': 22, 'startIndex': 32, 'v...
# 1      [{'age': {'endIndex': 22, 'startIndex': 32, 'v...
# 2      [{'age': {'endIndex': 65, 'startIndex': 54, 'v...  white
# 3      [{'age': {'endIndex': 56, 'startIndex': 54, 'v...  white
# 4      [{'age': {'endIndex': -1, 'startIndex': -1, 'v...
# ...                                                  ...    ...
# 23898  [{'age': {'endIndex': 182, 'startIndex': 179, ...    NaN
# 23899  [{'age': {'endIndex': 543, 'startIndex': 540, ...    NaN
# 23900  [{'age': {'endIndex': 57, 'startIndex': 55, 'v...    NaN
# 23901  [{'age': {'endIndex': 100, 'startIndex': 98, '...  white
# 23902  [{'age': {'endIndex': 63, 'startIndex': 61, 'v...
#
#                                          tokenized_title  \
# 0      [Man, shoots, self, accidentally, while, in, car]
# 1      [Man, shoots, self, accidentally, while, in, car]
# 2      [Man, accidentally, shoots, himself, cleaning,...
# 3      [Man, accidentally, shoots, himself, cleaning,...
# 4      [Man, shoots, self, accidentally, while, in, car]
# ...                                                  ...
# 23898  [Woman, Dies, After, Being, Shot, in, Head, Al...
# 23899  [Bridgeport, man, murdered, in, 9th, homocide,...
# 23900    [23, year, old, man, shot, dead, in, nightclub]
# 23901  [Man, accidentally, shoots, himself, cleaning,...
# 23902  [Man, shoots, self, accidentally, while, in, car]
#
#                                               title_vect
# 0        (0, 1721)\t0.4563040367696755\n  (0, 4737)\t...
# 1        (0, 1721)\t0.4563040367696755\n  (0, 4737)\t...
# 2        (0, 4232)\t0.3975455962537428\n  (0, 2105)\t...
# 3        (0, 4232)\t0.3975455962537428\n  (0, 2105)\t...
# 4        (0, 1721)\t0.4563040367696755\n  (0, 4737)\t...
# ...                                                  ...
# 23898    (0, 6671)\t0.47231057503642304\n  (0, 4385)\...
# 23899    (0, 9142)\t0.39417476630777765\n  (0, 4554)\...
# 23900    (0, 91)\t0.47361831369364255\n  (0, 6681)\t0...
# 23901    (0, 4232)\t0.3975455962537428\n  (0, 2105)\t...
# 23902    (0, 1721)\t0.4563040367696755\n  (0, 4737)\t...
#
# [23903 rows x 15 columns]

# %%
print(df['title_vect'][0])
# Out:
#   (0, 1721)	0.4563040367696755
#   (0, 4737)	0.13795119470958206
#   (0, 9904)	0.452601971846722
#   (0, 306)	0.4100683058394725
#   (0, 8294)	0.44386713360405866
#   (0, 8435)	0.3976772299113978
#   (0, 5922)	0.21115473484725697

# %%
(df.race == 'african-american').sum()
# Out:
# 10

# %%
((df.race != 'white') & (df.race !='') & (df.race !='NaN')).sum()
# Out:
# 925

# %%
((df.race == 'hispanic') | (df.race == 'asian') | (df.race == 'mexican') | (df.race == 'black') | (df.race == 'African American') | (df.race == 'Asian-American') | (df.race == 'Afrian-American') | (df.race == 'Asian-American') ).sum()
# Out:
# 491

# %%
df['race'] = df.race.str.lower()
aa_arr = []
asian_arr = []
hisp_arr = [] 
white_arr = []
empty_arr = []

# %%
aa_arr = (df.index[df.race == 'black']) | (df.index[df.race == 'african']) | (df.index[df.race == 'african-american']) | (df.index[df.race == 'african american'])
asian_arr = (df.index[df.race == 'asian']) | (df.index[df.race == 'asian-american']) | (df.index[df.race == 'asian american']) | (df.index[df.race == 'chinese']) | (df.index[df.race == 'chinese-american']) | (df.index[df.race == 'chinese american']) | (df.index[df.race == 'vietnamese']) | (df.index[df.race == 'korean'])  
hisp_arr = (df.index[df.race == 'hispanic']) | (df.index[df.race == 'mexican'])
white_arr = (df.index[df.race == 'white']) | (df.index[df.race == 'caucasian'])
empty_arr = (df.index[df.race == 'nan']) | (df.index[df.race == ''])
# Out:
# <ipython-input-33-6661ce9a9c2f>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   aa_arr = (df.index[df.race == 'black']) | (df.index[df.race == 'african']) | (df.index[df.race == 'african-american']) | (df.index[df.race == 'african american'])
# <ipython-input-33-6661ce9a9c2f>:2: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   asian_arr = (df.index[df.race == 'asian']) | (df.index[df.race == 'asian-american']) | (df.index[df.race == 'asian american']) | (df.index[df.race == 'chinese']) | (df.index[df.race == 'chinese-american']) | (df.index[df.race == 'chinese american']) | (df.index[df.race == 'vietnamese']) | (df.index[df.race == 'korean'])
# <ipython-input-33-6661ce9a9c2f>:3: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   hisp_arr = (df.index[df.race == 'hispanic']) | (df.index[df.race == 'mexican'])
# <ipython-input-33-6661ce9a9c2f>:4: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   white_arr = (df.index[df.race == 'white']) | (df.index[df.race == 'caucasian'])
# <ipython-input-33-6661ce9a9c2f>:5: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   empty_arr = (df.index[df.race == 'nan']) | (df.index[df.race == ''])

# %%
race_dict = {}
race_dict['aa'] = list(aa_arr)
race_dict['asian'] = list(asian_arr)
race_dict['hispanic'] = list(hisp_arr)
race_dict['white'] = list(white_arr)
race_dict
# Out:
# {'aa': [250,
#   263,
#   278,
#   293,
#   356,
#   528,
#   538,
#   624,
#   630,
#   673,
#   691,
#   865,
#   891,
#   940,
#   979,
#   1034,
#   1083,
#   1281,
#   1288,
#   1443,
#   1895,
#   1898,
#   1922,
#   2196,
#   2462,
#   2972,
#   3118,
#   3599,
#   3675,
#   3696,
#   3705,
#   3771,
#   3789,
#   3839,
#   3862,
#   3876,
#   4133,
#   4154,
#   4246,
#   4397,
#   4431,
#   4523,
#   4524,
#   4528,
#   4645,
#   4653,
#   4908,
#   4992,
#   5027,
#   5033,
#   5051,
#   5056,
#   5134,
#   5436,
#   5440,
#   5452,
#   5473,
#   5700,
#   5733,
#   5742,
#   5816,
#   5874,
#   5887,
#   5898,
#   5972,
#   5974,
#   5982,
#   5989,
#   6080,
#   6112,
#   6203,
#   6212,
#   6231,
#   6380,
#   6602,
#   6655,
#   6692,
#   6729,
#   6817,
#   6825,
#   6913,
#   6923,
#   6939,
#   6941,
#   6960,
#   6963,
#   6968,
#   6969,
#   6973,
#   6974,
#   6977,
#   6979,
#   7000,
#   7054,
#   7061,
#   7062,
#   7076,
#   7079,
#   7080,
#   7081,
#   7207,
#   7209,
#   7282,
#   7300,
#   7318,
#   7331,
#   7332,
#   7345,
#   7390,
#   7403,
#   7416,
#   7433,
#   7467,
#   7473,
#   7486,
#   7529,
#   7540,
#   7544,
#   7545,
#   7552,
#   7567,
#   7573,
#   7643,
#   7655,
#   7734,
#   7759,
#   7807,
#   7842,
#   7918,
#   7934,
#   7994,
#   8084,
#   8116,
#   8262,
#   8288,
#   8361,
#   8375,
#   8417,
#   8425,
#   8456,
#   8461,
#   8486,
#   8493,
#   8546,
#   8589,
#   8637,
#   8640,
#   8718,
#   8729,
#   8767,
#   8768,
#   8829,
#   8924,
#   8934,
#   9062,
#   9091,
#   9151,
#   9179,
#   9347,
#   9426,
#   9452,
#   9484,
#   9492,
#   9512,
#   9517,
#   9519,
#   9520,
#   9524,
#   9525,
#   9533,
#   9549,
#   9553,
#   9560,
#   9561,
#   9635,
#   9834,
#   9851,
#   10021,
#   10105,
#   10135,
#   10182,
#   10195,
#   10233,
#   10271,
#   10387,
#   10408,
#   10485,
#   10584,
#   10773,
#   10778,
#   10826,
#   10863,
#   10877,
#   10890,
#   10898,
#   10960,
#   10969,
#   11029,
#   11276,
#   11328,
#   11362,
#   11365,
#   11390,
#   11540,
#   11813,
#   11822,
#   12020,
#   12065,
#   12070,
#   12096,
#   12116,
#   12124,
#   12161,
#   12208,
#   12301,
#   12365,
#   12405,
#   12415,
#   12509,
#   12511,
#   12553,
#   12586,
#   12595,
#   12608,
#   12664,
#   12686,
#   12689,
#   12710,
#   12719,
#   12734,
#   12790,
#   12813,
#   12842,
#   12851,
#   12860,
#   12875,
#   12882,
#   12930,
#   12966,
#   13014,
#   13096,
#   13117,
#   13119,
#   13213,
#   13289,
#   13342,
#   13367,
#   13402,
#   13407,
#   13429,
#   13503,
#   13589,
#   13598,
#   13607,
#   13619,
#   13632,
#   13635,
#   13636,
#   13637,
#   13640,
#   13643,
#   13644,
#   13647,
#   13655,
#   13656,
#   13662,
#   13663,
#   13665,
#   13666,
#   13667,
#   13668,
#   13670,
#   13671,
#   13830,
#   13835,
#   13962,
#   14025,
#   14167,
#   14210,
#   14297,
#   14312,
#   14357,
#   14388,
#   14591,
#   14615,
#   14632,
#   15136,
#   15334,
#   15498,
#   16234,
#   16367,
#   16420,
#   16423,
#   16424,
#   16425,
#   16426,
#   16427,
#   16429,
#   16438,
#   16440,
#   16462,
#   16470,
#   16474,
#   17344,
#   17592,
#   17597,
#   18173,
#   18174,
#   18353,
#   18450,
#   18461,
#   18503,
#   18667,
#   18685,
#   18704,
#   18784,
#   18788,
#   18870,
#   18905,
#   18996,
#   19031,
#   19068,
#   19090,
#   19104,
#   19107,
#   19110,
#   19145,
#   19152,
#   19204,
#   19506,
#   19518,
#   19663,
#   19685,
#   19696,
#   19918,
#   19956,
#   20090,
#   20399,
#   20529,
#   20542,
#   20590,
#   20628,
#   20649,
#   20748,
#   20785,
#   20879,
#   20883,
#   20926,
#   20934,
#   20958,
#   20961,
#   21006,
#   21028,
#   21037,
#   21071,
#   21111,
#   21115,
#   21141,
#   21159,
#   21162,
#   21173,
#   21192,
#   21292,
#   21324,
#   21327,
#   21421,
#   21468,
#   21479,
#   21517,
#   21564,
#   21579,
#   21613,
#   21671,
#   21819,
#   21841,
#   21844,
#   21865,
#   21904,
#   21967,
#   21986,
#   22013,
#   22027,
#   22039,
#   22068,
#   22082,
#   22088,
#   22131,
#   22166,
#   22216,
#   22268,
#   22277,
#   22335,
#   22352,
#   22424,
#   22444,
#   22463,
#   22495,
#   22502,
#   22518,
#   22542,
#   22606,
#   22609,
#   22678,
#   22679,
#   22682,
#   22702,
#   22708,
#   22744,
#   22801,
#   22843,
#   22897,
#   22929,
#   22950,
#   22979,
#   22983,
#   23033,
#   23096,
#   23129,
#   23151,
#   23215,
#   23282,
#   23303,
#   23304,
#   23347,
#   23355,
#   23417,
#   23426,
#   23546,
#   23548,
#   23563,
#   23621,
#   23636,
#   23669,
#   23676,
#   23717,
#   23719,
#   23755,
#   23789,
#   23791,
#   23811,
#   23824,
#   23864,
#   23870,
#   23871,
#   23879],
#  'asian': [3105,
#   4349,
#   4858,
#   6670,
#   6860,
#   7753,
#   10769,
#   10867,
#   13026,
#   13059,
#   14195,
#   16095,
#   19185,
#   19228,
#   19231,
#   19522,
#   20478,
#   21497,
#   21516,
#   21605,
#   21640,
#   21645,
#   21719,
#   21724,
#   21790,
#   21797,
#   22985,
#   23459],
#  'hispanic': [289,
#   1428,
#   2339,
#   3539,
#   3554,
#   4795,
#   4809,
#   4828,
#   4894,
#   4970,
#   5750,
#   6162,
#   6199,
#   6241,
#   6300,
#   6305,
#   6471,
#   6490,
#   6674,
#   6675,
#   6836,
#   7175,
#   7627,
#   8302,
#   8377,
#   8622,
#   8757,
#   9410,
#   9908,
#   12215,
#   12854,
#   13897,
#   14549,
#   15602,
#   15670,
#   18651,
#   19443,
#   19880,
#   19886,
#   20496,
#   20776,
#   20922,
#   21062,
#   21870,
#   22431,
#   22450,
#   22701,
#   22707,
#   22844,
#   23004,
#   23187,
#   23230],
#  'white': [2,
#   3,
#   5,
#   8,
#   9,
#   19,
#   20,
#   22,
#   25,
#   32,
#   40,
#   43,
#   46,
#   50,
#   80,
#   81,
#   84,
#   85,
#   89,
#   95,
#   101,
#   113,
#   121,
#   124,
#   132,
#   137,
#   153,
#   155,
#   158,
#   165,
#   166,
#   167,
#   169,
#   177,
#   182,
#   187,
#   188,
#   192,
#   206,
#   217,
#   219,
#   222,
#   225,
#   227,
#   243,
#   244,
#   246,
#   248,
#   266,
#   272,
#   274,
#   284,
#   290,
#   291,
#   292,
#   294,
#   299,
#   305,
#   311,
#   314,
#   317,
#   320,
#   324,
#   330,
#   331,
#   333,
#   340,
#   345,
#   348,
#   357,
#   358,
#   363,
#   364,
#   367,
#   371,
#   417,
#   689,
#   1080,
#   1090,
#   1091,
#   1408,
#   1492,
#   1519,
#   1802,
#   1807,
#   1884,
#   1985,
#   2321,
#   2460,
#   2461,
#   2517,
#   2711,
#   2784,
#   2956,
#   3122,
#   3197,
#   3524,
#   3532,
#   3587,
#   3636,
#   3691,
#   3721,
#   3912,
#   4047,
#   4059,
#   4087,
#   4206,
#   4269,
#   4386,
#   4393,
#   4759,
#   4760,
#   4844,
#   4951,
#   5040,
#   5067,
#   5099,
#   5226,
#   5236,
#   5282,
#   5430,
#   5615,
#   5649,
#   5669,
#   5677,
#   5683,
#   5695,
#   5764,
#   5815,
#   5822,
#   5926,
#   5948,
#   6091,
#   6092,
#   6122,
#   6403,
#   6577,
#   6704,
#   6854,
#   6862,
#   6925,
#   7065,
#   7264,
#   7283,
#   7284,
#   7307,
#   7379,
#   7402,
#   7607,
#   7609,
#   8092,
#   8154,
#   9157,
#   9243,
#   9251,
#   9441,
#   9590,
#   9794,
#   10148,
#   10149,
#   10150,
#   10227,
#   10489,
#   10696,
#   11301,
#   11580,
#   11584,
#   11628,
#   11695,
#   11843,
#   12067,
#   12331,
#   12569,
#   12704,
#   12714,
#   12884,
#   12921,
#   13050,
#   13052,
#   13146,
#   13240,
#   13310,
#   13370,
#   13435,
#   13601,
#   13703,
#   13709,
#   13922,
#   14112,
#   14194,
#   14207,
#   14373,
#   14438,
#   14450,
#   14584,
#   14856,
#   14864,
#   14953,
#   14956,
#   15002,
#   15164,
#   15165,
#   15248,
#   15252,
#   15346,
#   15347,
#   15587,
#   15656,
#   15740,
#   15751,
#   15802,
#   16273,
#   16287,
#   16557,
#   16558,
#   16559,
#   18355,
#   18674,
#   18683,
#   18695,
#   18698,
#   18745,
#   18835,
#   19001,
#   19006,
#   19078,
#   19093,
#   19396,
#   19422,
#   19661,
#   19713,
#   19823,
#   19933,
#   20078,
#   20282,
#   20354,
#   20377,
#   20589,
#   20791,
#   20795,
#   21401,
#   21511,
#   21536,
#   21540,
#   21545,
#   21718,
#   21768,
#   21843,
#   21856,
#   21861,
#   21864,
#   21947,
#   22278,
#   22285,
#   22417,
#   22584,
#   22731,
#   22745,
#   22760,
#   22838,
#   23228,
#   23294,
#   23308,
#   23400,
#   23772,
#   23825,
#   23901]}

# %%
race_dict_lens = {}
race_dict_lens['aa'] = len(race_dict['aa'])
race_dict_lens['asian'] = len(race_dict['asian'])
race_dict_lens['hispanic'] = len(race_dict['hispanic'])
race_dict_lens['white'] = len(race_dict['white'])
df_r=pd.DataFrame.from_dict(race_dict_lens,orient='index').transpose()
sns.set_theme(style="whitegrid")
ax = sns.barplot(data=df_r)

# %%
white_token_dict = {};
for row in race_dict['white']:
    for word in (df['tokenized_title'][row]):
        if word in white_token_dict:
            white_token_dict[word.lower()] = white_token_dict[word.lower()] + 1
        else:
            white_token_dict[word.lower()] = 1
poc_token_dict = {};
for row in race_dict['aa']:
    for word in (df['tokenized_title'][row]):
        if word in poc_token_dict:
            poc_token_dict[word.lower()] = poc_token_dict[word.lower()] + 1
        else:
            poc_token_dict[word.lower()] = 1
for row in race_dict['asian']:
    for word in (df['tokenized_title'][row]):
        if word in poc_token_dict:
            poc_token_dict[word.lower()] = poc_token_dict[word.lower()] + 1
        else:
            poc_token_dict[word.lower()] = 1
for row in race_dict['hispanic']:
    for word in (df['tokenized_title'][row]):
        if word in poc_token_dict:
            poc_token_dict[word.lower()] = poc_token_dict[word.lower()] + 1
        else:
            poc_token_dict[word.lower()] = 1

# %%
poc_token_dict
# Out:
# {'police': 1,
#  'say': 8,
#  'shooting': 4,
#  'near': 1,
#  'city': 1,
#  'market': 1,
#  'injured': 2,
#  '5': 4,
#  ',': 375,
#  'not': 2,
#  '3': 4,
#  '-': 426,
#  'identify': 5,
#  'suspect': 2,
#  'in': 9,
#  'memphis': 1,
#  'officer': 1,
#  "'s": 24,
#  'killing': 1,
#  'arrested': 10,
#  'cop': 5,
#  '12': 8,
#  'news': 1,
#  'ex-con': 1,
#  'accused': 62,
#  'of': 16,
#  'turns': 60,
#  'self': 60,
#  'woman': 1,
#  'finds': 1,
#  'gunshot': 4,
#  'victim': 7,
#  'lex18.com': 1,
#  '|': 193,
#  'continuous': 1,
#  'and': 8,
#  'stormtracker': 1,
#  'weather': 1,
#  'two': 5,
#  'by': 11,
#  'gunfire': 3,
#  'north': 1,
#  'champaign': 1,
#  'news-gazette.com': 1,
#  'contracostatimes.com': 1,
#  'manhunt': 1,
#  'underway': 1,
#  'for': 26,
#  'fatal': 11,
#  'journal': 1,
#  'star': 1,
#  'peoria': 1,
#  'il': 1,
#  'portland': 1,
#  'seek': 10,
#  'public': 3,
#  'help': 1,
#  'solving': 2,
#  '2005': 2,
#  'homicide': 1,
#  'ktre.com': 1,
#  'lufkin': 1,
#  'nacogdoches': 1,
#  'texas': 1,
#  'nopd': 1,
#  'releases': 4,
#  'new': 1,
#  'video': 3,
#  'lower': 1,
#  'garden': 1,
#  'district': 1,
#  'orleans': 1,
#  'wdsu': 1,
#  'home': 1,
#  'fox': 1,
#  '32': 6,
#  'msnewsnow.com': 1,
#  'jackson': 1,
#  'ms': 1,
#  'deputies': 2,
#  'investigating': 1,
#  'at': 11,
#  'richland': 1,
#  'terrace': 1,
#  'apartment': 4,
#  'co': 25,
#  'wistv.com': 26,
#  'columbia': 1,
#  'south': 1,
#  'carolina': 1,
#  'search': 1,
#  'gunman': 1,
#  'after': 1,
#  'el': 1,
#  'pollo': 1,
#  'loco': 1,
#  'robbed': 8,
#  'cathedral': 1,
#  '2': 19,
#  'men': 2,
#  'gunpoint': 7,
#  'dollar': 1,
#  'general': 1,
#  'on': 4,
#  'amber': 1,
#  'dr.': 1,
#  'wtvm.com-columbus': 1,
#  'ga': 1,
#  '&': 35,
#  'sports': 1,
#  'teen': 2,
#  'riding': 1,
#  'bike': 1,
#  'shot': 22,
#  'to': 14,
#  'death': 6,
#  'fuller': 1,
#  'street': 1,
#  'dorchester': 1,
#  'reporter': 1,
#  'paso': 1,
#  'times': 1,
#  'stockton': 1,
#  'man': 1,
#  'truck': 1,
#  'dies': 1,
#  'hospital': 3,
#  'suspects': 5,
#  'fox40': 1,
#  'wtoc-tv': 1,
#  ':': 80,
#  'savannah': 1,
#  'beaufort': 1,
#  'sc': 1,
#  'sheriff': 1,
#  '?': 2,
#  's': 7,
#  'reports': 1,
#  'believing': 1,
#  'he': 3,
#  'had': 1,
#  'killed': 1,
#  'girlfriend': 1,
#  'during': 14,
#  'assault': 2,
#  'springfield': 1,
#  ';': 12,
#  'fired': 7,
#  'pontiac': 1,
#  'residence': 1,
#  'one': 1,
#  'women': 4,
#  'fatally': 2,
#  'was': 4,
#  'pregnant': 2,
#  'family': 2,
#  'says': 3,
#  'identified': 4,
#  'national': 1,
#  'wlky': 1,
#  'female': 1,
#  'employee': 2,
#  'outside': 2,
#  'gentlemen': 2,
#  'club': 2,
#  'critically': 3,
#  'being': 1,
#  'dc': 1,
#  'sought': 1,
#  'hpd': 1,
#  'photos': 2,
#  'grocery': 2,
#  'store': 6,
#  'robbery': 8,
#  'gang': 1,
#  'member': 2,
#  'sentenced': 1,
#  '85': 1,
#  'years': 1,
#  'life': 1,
#  '2013': 1,
#  'the': 2,
#  'report': 1,
#  'los': 1,
#  'angeles': 1,
#  'macon': 1,
#  'allegedly': 2,
#  'assaulted': 2,
#  'bibb': 1,
#  'ktbs.com': 1,
#  'shreveport': 1,
#  'la': 1,
#  'cherokee': 1,
#  'tribune': 1,
#  'canton': 1,
#  'investigators': 1,
#  'following': 3,
#  'leads': 1,
#  'bar': 6,
#  'no': 6,
#  'coward': 1,
#  'wdrb': 1,
#  '41': 3,
#  'louisville': 1,
#  'waff-tv': 1,
#  'huntsville': 1,
#  'al': 1,
#  'friends': 1,
#  'question': 1,
#  'chief': 3,
#  'wtvr.com': 1,
#  'overnight': 5,
#  'wound': 1,
#  'head': 4,
#  '7news': 1,
#  'boston': 1,
#  'whdh-tv': 1,
#  'denver': 1,
#  'post': 1,
#  'phoenix': 1,
#  'release': 2,
#  'lead': 1,
#  'murder': 4,
#  'transgender': 1,
#  'protecting': 2,
#  'sister': 1,
#  'houston': 1,
#  'abc13.com': 7,
#  'overpowers': 1,
#  'three': 1,
#  'shoots': 3,
#  'attack': 1,
#  'breaking': 1,
#  'wciv': 1,
#  'bowling': 1,
#  'alley': 1,
#  'flushing': 1,
#  'queens': 1,
#  'abc7ny.com': 2,
#  'continue': 1,
#  'shooter': 4,
#  'amarillo': 1,
#  'globe-news': 1,
#  'from': 3,
#  'sw': 1,
#  'west': 1,
#  'philadelphia': 1,
#  '6abc.com': 6,
#  'mom': 1,
#  'daughter': 1,
#  'targeted': 1,
#  'with': 4,
#  'face': 5,
#  'hidden': 1,
#  'scarf': 1,
#  'linden': 1,
#  'jersey': 1,
#  'coroner': 1,
#  'identifies': 1,
#  'ashley': 1,
#  'barbershop': 1,
#  'visiting': 1,
#  'san': 1,
#  'jacinto': 1,
#  'neighborhood': 3,
#  '1': 19,
#  'dead': 12,
#  'wounded': 1,
#  'abc7.com': 1,
#  'investigate': 1,
#  'hamlet': 1,
#  'elementary': 1,
#  'southern': 1,
#  'university': 1,
#  'student': 1,
#  'as': 1,
#  'brent': 1,
#  'randall': 1,
#  'kltv.com-tyler': 1,
#  'longview': 1,
#  'jacksonville': 1,
#  'etx': 1,
#  'ksla': 1,
#  'louisiana': 1,
#  'wlox.com': 1,
#  'mississippi': 1,
#  'deadly': 1,
#  'hit': 1,
#  'run': 2,
#  'wapt': 1,
#  'shootings': 2,
#  'that': 4,
#  'appear': 3,
#  'random': 4,
#  '4-year-old': 1,
#  'girl': 1,
#  'held': 1,
#  '59': 4,
#  'pedestrian': 1,
#  'cooney': 1,
#  'circle': 1,
#  'augusta': 1,
#  'chronicle': 1,
#  'evanston': 1,
#  '«': 22,
#  'cbs': 1,
#  'chicago': 1,
#  'grpd': 1,
#  'through': 1,
#  'windshield': 1,
#  'fight': 3,
#  'fox17': 1,
#  'caught': 2,
#  'camera': 2,
#  'cab': 1,
#  'driver': 1,
#  'retrieve': 1,
#  'inside': 3,
#  'vehicle': 5,
#  'fox6now.com': 1,
#  'clerks': 1,
#  'dallas': 1,
#  'school': 1,
#  '/': 8,
#  'fort': 1,
#  'worth': 1,
#  'armed': 1,
#  'dangerous': 15,
#  'wauwatosa': 1,
#  'need': 1,
#  'your': 1,
#  'identifying': 1,
#  'amf': 1,
#  'bowlero': 1,
#  'lanes': 1,
#  'shawnee': 1,
#  'locating': 1,
#  'suspected': 4,
#  'fox4kc.com': 2,
#  'mourns': 1,
#  'one-year-old': 1,
#  'baby': 2,
#  'is': 2,
#  'crib': 1,
#  'defender': 1,
#  'troy': 1,
#  'wrgb': 1,
#  'grand': 1,
#  'rapids': 1,
#  'i-80/94': 1,
#  'indiana': 1,
#  'road': 2,
#  'rage': 2,
#  'incident': 2,
#  'large': 2,
#  'benihana': 1,
#  'restaurant': 2,
#  'detroit': 1,
#  'northeast': 1,
#  '7-eleven': 1,
#  'morning': 7,
#  '14-year-old': 2,
#  'feels': 1,
#  'responsible': 1,
#  'over': 2,
#  'fox2now.com': 1,
#  'charged': 1,
#  'felony': 1,
#  'baltimore': 1,
#  'beauty': 1,
#  'known': 1,
#  'motive': 1,
#  'wbff': 1,
#  'ferguson': 1,
#  'early': 3,
#  'saturday': 1,
#  'msu': 1,
#  'off-campus': 1,
#  'still': 1,
#  'april': 1,
#  '2011': 1,
#  'chest': 2,
#  'critical': 3,
#  'argument': 1,
#  'park': 1,
#  'found': 6,
#  'car': 5,
#  'bridge': 1,
#  'manor': 1,
#  'drive': 1,
#  'back': 2,
#  'east': 3,
#  'side': 1,
#  'while': 4,
#  'fleeing': 1,
#  'unt': 1,
#  'identity': 1,
#  'convenience': 1,
#  'clerk': 4,
#  'attempted': 2,
#  'cyclist': 1,
#  'charges': 1,
#  'filed': 1,
#  'against': 1,
#  'york': 1,
#  'county': 1,
#  'wpmt': 1,
#  'fox43': 1,
#  '’': 13,
#  'office': 1,
#  'shots': 3,
#  'into': 2,
#  'i-43': 1,
#  'nb': 1,
#  'between': 2,
#  'hampton': 1,
#  'silver': 1,
#  'spring': 1,
#  '17th': 1,
#  'kenyon': 1,
#  'injuries': 1,
#  'seattle': 1,
#  'herald': 1,
#  'white': 2,
#  'center': 2,
#  'gulfport': 1,
#  'looking': 17,
#  "'armed": 13,
#  "'": 19,
#  'suspe': 13,
#  'bert': 1,
#  'crump': 1,
#  'jr.': 1,
#  '17': 3,
#  'joseph': 1,
#  'edward': 1,
#  'beaman': 1,
#  '36': 4,
#  'isaac': 1,
#  'lashon': 1,
#  'tobias': 1,
#  '23': 10,
#  'charles': 1,
#  'logan': 1,
#  'gladys': 1,
#  'bloodworth': 1,
#  '64': 1,
#  'hermilo': 1,
#  'talamantez': 1,
#  'iii': 1,
#  '34': 2,
#  'jeremy': 1,
#  'solomon': 1,
#  '20': 6,
#  'filimon': 1,
#  'lamas': 1,
#  '33': 3,
#  'irene': 1,
#  'cardenas': 1,
#  '35': 1,
#  'andy': 1,
#  'bonilla': 1,
#  '18': 6,
#  'jasmine': 1,
#  'sanders': 1,
#  '8': 1,
#  'eddie': 1,
#  'green': 1,
#  '31': 2,
#  'john': 1,
#  'westley': 1,
#  'matthews': 1,
#  'felton': 1,
#  'millage': 1,
#  '47': 2,
#  'deandre': 1,
#  'millender': 1,
#  '25': 5,
#  'dennys': 1,
#  'pacheco': 1,
#  '19': 4,
#  'gerald': 1,
#  'smith': 1,
#  '54': 1,
#  'dion': 1,
#  'johnson': 1,
#  'calvin': 1,
#  'williams': 1,
#  '38': 5,
#  'francisco': 1,
#  'revolorio': 1,
#  '46': 2,
#  'aldale': 1,
#  'woodard': 1,
#  '27': 1,
#  'darren': 1,
#  'turner': 1,
#  '40': 3,
#  'frankie': 1,
#  'ogburn': 1,
#  '24': 3,
#  '[': 2,
#  'updated': 1,
#  ']': 2,
#  'derrick': 1,
#  'anthony': 1,
#  'hill': 1,
#  '48': 1,
#  'conrad': 1,
#  'phillip': 1,
#  'jermaine': 1,
#  'watson': 1,
#  'aveion': 1,
#  'curtis': 1,
#  'bolden': 1,
#  'gary': 1,
#  'lacey': 1,
#  'ii': 1,
#  'dean': 1,
#  'hyde': 1,
#  '44': 1,
#  'tillman': 1,
#  '30': 3,
#  'jerome': 1,
#  'stallworth': 1,
#  'dominique': 1,
#  'mcdaniels': 1,
#  'davon': 1,
#  'brance': 1,
#  'andre': 1,
#  'jerod': 1,
#  'lowe': 1,
#  'donte': 1,
#  'catchings': 1,
#  'eric': 1,
#  'mario': 1,
#  'desarden': 1,
#  '28': 4,
#  'diego': 1,
#  'garcia': 1,
#  'roland': 1,
#  'buckner': 1,
#  '42': 1,
#  'allen': 1,
#  'luther': 1,
#  'thomas': 1,
#  'henry': 1,
#  'serrano': 1,
#  '56': 1,
#  'howard': 1,
#  'jerica': 1,
#  'denise': 1,
#  'owens': 1,
#  'josimar': 1,
#  'rojas': 1,
#  '26': 2,
#  'lying': 1,
#  'her': 1,
#  'cot': 1,
#  'giovani': 1,
#  '4': 3,
#  'domonick': 1,
#  'anderson': 1,
#  'jorge': 1,
#  'barrios': 1,
#  'alvarado': 1,
#  '43': 3,
#  'bobby': 1,
#  'jose': 1,
#  'magana': 1,
#  '57': 1,
#  'edwardo': 1,
#  'avila': 1,
#  '14': 1,
#  'delray': 1,
#  'yarbrough': 1,
#  'bryant': 1,
#  'tennelle': 1,
#  'alexander': 1,
#  'neal': 1,
#  'jarrod': 1,
#  'sellers': 1,
#  'joshua': 1,
#  'flynn': 1,
#  'andrew': 1,
#  'peppers': 1,
#  '16': 1,
#  'hernan': 1,
#  'cardona': 1,
#  '60': 1,
#  'emitt': 1,
#  'love': 1,
#  'harold': 1,
#  'germany': 1,
#  '21': 2,
#  'sullivan': 1,
#  '53': 1,
#  'jenny': 1,
#  'sor': 1,
#  'jonathan': 1,
#  'ford': 1,
#  '45': 1,
#  'bryan': 1,
#  'hollis': 1,
#  'davion': 1,
#  'deshoun': 1,
#  'washington': 1,
#  'danny': 1,
#  'horn': 1,
#  'jacinta': 1,
#  'walker': 1,
#  'joel': 1,
#  'leach': 1,
#  'konelio': 1,
#  'tagoai': 1,
#  '29': 1,
#  'eder': 1,
#  'pineda-hernandez': 1,
#  'earl': 1,
#  'milwaukee': 1,
#  '24-year-old': 1,
#  'gunmen': 2,
#  'burst': 1,
#  'person': 2,
#  'state': 1,
#  'emergency': 1,
#  'declared': 1,
#  'latest': 1,
#  'stevelind': 1,
#  'mouten': 1,
#  '22': 2,
#  'wilson': 1,
#  'rodriguez': 1,
#  'willie': 1,
#  'singleton': 1,
#  'kidnapped': 4,
#  'stabbed': 1,
#  'brooklyn': 1,
#  'fbi': 1,
#  '—': 2,
#  'increases': 1,
#  'reward': 3,
#  'money': 1,
#  'information': 2,
#  'unarmed': 3,
#  'naked': 1,
#  'ny': 1,
#  'daily': 1,
#  'seeking': 1,
#  'lubbock': 1,
#  'online': 1,
#  'avalanche-journal': 1,
#  'michael': 1,
#  'mpd': 1,
#  'dinkytown': 1,
#  'wcco': 1,
#  'minnesota': 1,
#  'keyonta': 1,
#  'muhammad': 1,
#  'ansari': 1,
#  'apartments': 4,
#  'custody': 1,
#  'kfda': 1,
#  'newschannel': 1,
#  '10': 11,
#  'myrtle': 1,
#  'beach': 1,
#  'thu': 1,
#  'wmbfnews.com': 1,
#  'beach/florence': 1,
#  'golocalworcester': 1,
#  'worcester': 1,
#  'pd': 1,
#  'wellington': 1,
#  'cordele': 1,
#  'walb.com': 1,
#  'georgia': 1,
#  'northwest': 1,
#  'rock': 1,
#  'sitting': 2,
#  'porch': 1,
#  'pistol-whipped': 1,
#  'sergeant': 13,
#  'execution-style': 13,
#  'sonic': 1,
#  'hamburg': 1,
#  'wanted': 2,
#  'neighbor': 3,
#  'unborn': 1,
#  'child': 1,
#  'has': 1,
#  'ties': 1,
#  'brampton': 1,
#  'leaves': 1,
#  'serious': 1,
#  'condition': 2,
#  'charleston': 1,
#  'gazette-mail': 1,
#  'violent': 1,
#  'feud': 1,
#  'may': 1,
#  'have': 1,
#  'led': 1,
#  'play': 1,
#  'atlantis': 1,
#  'thenewsherald.com': 3,
#  'waving': 1,
#  'gun': 3,
#  'prompts': 1,
#  'lockdowns': 1,
#  'massive': 1,
#  'wednesday': 1,
#  'name': 2,
#  'released': 1,
#  'night': 2,
#  'reported': 1,
#  'eastside': 1,
#  'savannahnow.com': 3,
#  'melvindale': 1,
#  'more': 1,
#  'plainview': 1,
#  'noon': 1,
#  'walmart': 1,
#  'watched': 1,
#  'assailant': 1,
#  'shoot': 1,
#  'kill': 2,
#  'savannah-chatham': 1,
#  'skidaway': 1,
#  'sycamore': 1,
#  'akron': 1,
#  'birthday': 1,
#  'party': 2,
#  'wkyc.com': 1,
#  'connection': 2,
#  'sunday': 1,
#  'local': 1,
#  'wcvb': 1,
#  'las': 1,
#  'vegas': 1,
#  'sun': 1,
#  'baton': 1,
#  'rouge': 1,
#  'officers': 2,
#  'chase': 1,
#  'al.com': 1,
#  'central': 1,
#  'review-journal': 1,
#  'clarksdale': 1,
#  "'he": 1,
#  'a': 3,
#  'fighter': 1,
#  'story': 1,
#  'birmingham': 1,
#  'msp': 1,
#  'investigates': 1,
#  'killings': 1,
#  'week': 1,
#  'apart': 1,
#  'inkster': 1,
#  'victims': 1,
#  'lured': 1,
#  'trap': 1,
#  'wxyz.com': 1,
#  'infant': 1,
#  'compton': 1,
#  "'talented": 1,
#  'musician': 1,
#  'gunned': 3,
#  'down': 3,
#  'gresham': 1,
#  'edenton': 1,
#  'advance': 1,
#  'l.a.': 1,
#  'shows': 3,
#  'carnell': 1,
#  'snell': 1,
#  'afro': 1,
#  'philly': 1,
#  'adult': 1,
#  'novelty': 1,
#  'shop': 1,
#  'nbc': 1,
#  'boutique': 1,
#  'cashier': 1,
#  'who': 4,
#  'paralyzed': 1,
#  'an': 1,
#  'discovered': 1,
#  'she': 1,
#  'four': 1,
#  'weeks': 1,
#  'somehow': 1,
#  'survived': 1,
#  'lawmaker': 1,
#  'traveling': 1,
#  'storm': 1,
#  'relief': 1,
#  'cam': 1,
#  'ogontz': 1,
#  'customer': 1,
#  'eatery': 1,
#  '‘': 5,
#  'table': 1,
#  'cleaning': 1,
#  'dispute': 1,
#  'rt': 1,
#  'america': 1,
#  'arrest': 2,
#  'middletown': 1,
#  'recordonline.com': 1,
#  'continues': 1,
#  'killer': 2,
#  'baylor': 1,
#  'charlotte': 1,
#  'won': 1,
#  't': 1,
#  'be': 1,
#  'made': 1,
#  'evidence': 1,
#  'it': 1,
#  'pointed': 1,
#  'q13': 1,
#  'pizza': 1,
#  'phillyvoice': 1,
#  'world': 1,
#  'curfew': 1,
#  'riots': 1,
#  'settlement': 1,
#  'outlined': 1,
#  'bridgeton': 1,
#  'seen': 1,
#  'upper': 1,
#  'darby': 1,
#  'studied': 1,
#  'move': 1,
#  'tactics': 1,
#  'black': 9,
#  'nationalism': 1,
#  'sniper': 1,
#  'cops': 2,
#  "'wanted": 1,
#  'people': 1,
#  'wife': 1,
#  'slain': 2,
#  'pot': 1,
#  'dispensary': 1,
#  'guard': 1,
#  'distraught': 1,
#  'angry': 1,
#  'delivery': 3,
#  'southwest': 1,
#  'persons': 4,
#  'interest': 6,
#  'triple': 1,
#  'camden': 1,
#  'investigation': 2,
#  'walking': 1,
#  'n.': 1,
#  'young': 1,
#  'northland': 1,
#  'mall': 1,
#  'talking': 2,
#  'pennsylvania': 1,
#  'house': 4,
#  'candidate': 2,
#  'pa.': 1,
#  'representatives': 1,
#  'parking': 2,
#  'lot': 2,
#  '6': 2,
#  'fairfield': 1,
#  'questioning': 1,
#  'double': 1,
#  'college': 1,
#  'roseland': 1,
#  'dnainfo.com': 1,
#  'oak': 1,
#  'forest': 1,
#  'michigan': 1,
#  'lindenman': 1,
#  'dayton': 1,
#  'www.daytondailynews.com': 1,
#  'patron': 1,
#  'opens': 2,
#  'fire': 1,
#  'wounds': 1,
#  'worker': 2,
#  'stickup': 1,
#  'late': 1,
#  'downtown': 1,
#  'wsav-tv': 1,
#  'scmpd.org': 1,
#  'update': 1,
#  'metro': 1,
#  'lynah': 1,
#  'trenton': 1,
#  'pharmacist': 1,
#  'attempt': 1,
#  'grazed': 1,
#  'bullet': 3,
#  'lake': 1,
#  'confrontation': 2,
#  'off-duty': 1,
#  'officials': 1,
#  'marshawn': 1,
#  'mccarrel': 1,
#  'activist': 1,
#  'commits': 1,
#  'suicide': 1,
#  'statehouse': 1,
#  'steps': 1,
#  'madamenoire': 1,
#  'uga': 1,
#  'delivering': 1,
#  'athens': 1,
#  'kings': 1,
#  'food': 1,
#  'wbrc': 1,
#  'fox6': 1,
#  'leg': 2,
#  'harlem': 1,
#  'searching': 2,
#  'wway': 1,
#  'tv3': 1,
#  'point': 1,
#  'breeze': 1,
#  'wsb-tv': 1,
#  "'urban": 1,
#  'terrorist': 1,
#  '7-11': 1,
#  'bart': 1,
#  'offers': 1,
#  '$': 2,
#  '10,000': 1,
#  'info': 1,
#  'oakland': 1,
#  'station': 4,
#  'broad': 1,
#  'daylight': 3,
#  'homewood': 1,
#  'id': 1,
#  'd': 1,
#  'wpxi': 1,
#  'maintenance': 1,
#  'nashville': 1,
#  'invasion': 2,
#  'wkrn': 1,
#  'tacoma': 1,
#  'image': 1,
#  'mynorthwest.com': 1,
#  'bpd': 1,
#  'o': 1,
#  '23abc': 1,
#  'pittsburgh': 1,
#  'gas': 3,
#  '58': 1,
#  'bridgeport': 1,
#  'connecticut': 1,
#  'bcso': 1,
#  'st.': 1,
#  'helena': 1,
#  'island': 1,
#  'juniata': 1,
#  'faced': 1,
#  'possible': 1,
#  'return': 1,
#  'prison': 1,
#  'lancaster': 1,
#  'antelope': 1,
#  'valley': 1,
#  'vigil': 1,
#  'planned': 1,
#  'fulto': 1,
#  'wmc': 1,
#  'action': 1,
#  'tennessee': 1,
#  'leghorn': 1,
#  'clayton': 1,
#  'www.ajc.com': 1,
#  'gwen': 1,
#  'goodman': 1,
#  'flags': 1,
#  'deputy': 1,
#  'wdtn': 1,
#  'virginia': 1,
#  'duluth': 1,
#  'comments': 1,
#  'prompted': 1,
#  'evacuations': 1,
#  'altercation': 1,
#  'warwick': 1,
#  'boulevard': 1,
#  'wavy-tv': 1,
#  'taken': 1,
#  'newport': 1,
#  'wtkr.com': 1,
#  '“': 1,
#  'lyft': 1,
#  '”': 1,
#  ...}
